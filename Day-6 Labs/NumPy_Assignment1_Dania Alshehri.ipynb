# %%
import numpy as np

# %% [markdown]
# ## Q#1: Create x array with elements equal to 1.

# %%
x = np.ones(3)
print(x)
# Out:
# [1. 1. 1.]

# %% [markdown]
# ## Q#2: Create y array with elements equal to 0.

# %%
y = np.zeros(3)
print(y)
# Out:
# [0. 0. 0.]

# %% [markdown]
# ## Q#3: Add x and y arrays.

# %%
add = x+y
print(add)
# Out:
# [1. 1. 1.]

# %% [markdown]
# ## Q#4: Print x array characteristics (e.g: dimension, shape, size, type).

# %%
print(x.ndim)
print(x.shape)
print(x.size)
print(x.dtype)
# Out:
# 1
# (3,)
# 3
# float64

# %% [markdown]
# ## Q#5: Create a 2D array "called w" as the following:
#
# |       |          |
# | ----- | -------- |
# | 11    | 12       |
# | 13    | 14       |
# | 15    | 16       |

# %%
w = np.array([[11, 12], [13, 14], [15, 16]])
print(w)
# Out:
# [[11 12]
#  [13 14]
#  [15 16]]

# %% [markdown]
# ## Q#6: Create z array contains the numbers from 1 to 3.

# %%
z = np.array([1, 2, 3])
print(z)
# Out:
# [1 2 3]

# %% [markdown]
# ## Q#7: Combine the arrays z and w in horizontal way then save it in a new variable "newArray".

# %%
#reshaped z to match the dimensions of w
re = z.reshape(-1, 1)
newArray = np.hstack((re, w))
print(newArray)
# Out:
# [[ 1 11 12]
#  [ 2 13 14]
#  [ 3 15 16]]

# %% [markdown]
# ## Q#8: Print all elements of "newArray" using the loop.

# %%
for i in newArray:
    for j in i:
        print(j)
# Out:
# 1
# 11
# 12
# 2
# 13
# 14
# 3
# 15
# 16

# %% [markdown]
# ## Q#9: Reverse the columns and rows of "newArray".

# %%
rev = newArray[::-1, ::-1]
print(rev)
# Out:
# [[16 15  3]
#  [14 13  2]
#  [12 11  1]]

# %% [markdown]
# ## Q#10: Decrement all elements of "newArray" with 1.

# %%
dec = newArray - 1
print(dec)
# Out:
# [[ 0 10 11]
#  [ 1 12 13]
#  [ 2 14 15]]

# %% [markdown]
# ## Q#11: Find smallest and biggest values in "newArray".

# %%
s = np.min(newArray)
m = np.max(newArray)
print(s, m)
# Out:
# 1 16

# %% [markdown]
# ## Q#12: Print the first row of "newArray" using indexing.

# %%
print(newArray[0])
# Out:
# [ 1 11 12]

# %% [markdown]
# ## Q#13: Print the number equals 12 of "newArray" using indexing.

# %%
num = newArray[0, 2]
print(num, newArray)
# Out:
# 12 [[ 1 11 12]
#  [ 2 13 14]
#  [ 3 15 16]]

# %% [markdown]
# ## Q#14: Print the numbers equal 0 and 13 of "newArray" using indexing.

# %%
num0 = newArray[0, 2]
num13 = newArray[1, 1]

print(num0,num13, newArray)
# Out:
# 12 13 [[ 1 11 12]
#  [ 2 13 14]
#  [ 3 15 16]]

# %% [markdown]
# ## Q#15: Change the shape of "newArray" to (9,1).

# %%
re9 = newArray.reshape(9, 1)
print(re9)
# Out:
# [[ 1]
#  [11]
#  [12]
#  [ 2]
#  [13]
#  [14]
#  [ 3]
#  [15]
#  [16]]

# %% [markdown]
# ## Q#16: Change the shape of "newArray" to (3,2).

# %%
re3= newArray.reshape(3, 2)
print(re3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 re3= newArray.reshape(3, 2)
#       2 print(re3)
#
# ValueError: cannot reshape array of size 9 into shape (3,2)

# %%
"""
We cant reshape to (3.2) because it requires 6 items 
and in newArray we have 9 items but we can reshape to (3.3)
"""
re4 = newArray.reshape(3, 3)
print(re4)

# %% [markdown]
# # Well Done 🎉
